# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Part 1 Obtaining Clan Data
# Through Postman and API request from official Royale API, we obtained 960 random clans, data which was obtained through Postman. Once obtained, data is stored as JSON, which is then cleaned to only filter into lsit 'tags'

# %%
import json
import requests
import urllib.parse
import csv
import pandas as pd
import concurrent.futures


# Load the JSON file into a Python object
with open('response.json', 'r',encoding='utf-8') as file:
    data = json.load(file)

# Extract the "tag" values and store them in a list
tags = []
for item in data['items']:
    tags.append(item['tag'])

print(tags) # Output: ['#LJQYQ9VC', '#9PUGLRLV', '#PURPR2CJ']

print(len(tags))
# Out:
# ['#LJQYQ9VC', '#PURPR2CJ', '#GQ0PU80C', '#GLLQC2L9', '#Q2U82LYC', '#Q2PGUQYL', '#GCPPV90V', '#GCYCRLYR', '#Q29C9PVR', '#QU8QQUPP', '#Q2CGRVV8', '#GLLRYRQL', '#Q29VGYPC', '#Q29CJL9Y', '#Q2CGRQYJ', '#GLLRCR2J', '#Q2P9LYGL', '#Q28V8P9L', '#QU800LYR', '#GGV2YG08', '#Q2JCLC8Y', '#Q8PJQUU9', '#Q29C9J8C', '#GLLQRULQ', '#QCPQ28UG', '#GGV2PQR0', '#QGYUJRQP', '#GCYP2V8G', '#QU8009C2', '#GGUUQQRQ', '#GCYP8PYJ', '#QGYYV0JR', '#QU80028Q', '#QU89Y8JJ', '#Q2PR0VPU', '#QUJ9J0RY', '#GGV20L8Y', '#QU29QYV9', '#Q2JRYRGP', '#GLLUYV90', '#GGUYQG9R', '#Q992Y80P', '#Q9JQGY2L', '#QU80J89P', '#QCPC2CJ8', '#GCPPVPY9', '#QU8L9LVV', '#GLQ9C99P', '#QCP02CP8', '#Q8GYPGVJ', '#QU880GCV', '#GCYVU9YV', '#GCPY0VUY', '#Q2C0U8GC', '#GCPYLYGV', '#Q28UQ9QJ', '#GCLGPQG2', '#Q29VPR2Y', '#Q8GYRYGP', '#Q2PGQG8Q', '#QCULGJJV', '#GLLRQ9JP', '#GLQPQPP8', '#Q2U2UYY0', '#Q920JQQY', '#QU299GYQ', '#QCPR2LRP', '#Q8YJYVGL', '#Q2PLJJJP', '#Q2U8228R', '#Q2PLC99J', '#Q2PYGQLJ', '#Q992L228', '#Q98RL0P0', '#GCYP22L0', '#GCPQ0GLV', '#QQU0RUUJ', '#Q2PYYJ9U', '#QRGLPG00', '#QL8YUVGG', '#80CLP2J9', '#LUJ2R8PC', '#YJPG28VJ', '#9RRPYJ0U', '#90CJ2QYV', '#QJLRJLJR', '#QCQL9PP8', '#L0LC2U', '#GPQ82VPJ', '#P8JVPR', '#QJ299CGC', '#8Q0CL0G2', '#QR9L8V0Q', '#PQVUQLCU', '#LUGJYLY9', '#2JUJP', '#JR8UR2Y', '#LVV0L8JG', '#PLY0YYVG', '#YVUQG0CJ', '#QQLPCRJJ', '#Q2C2U8QJ', '#Y8C9PVGL', '#CLY2VU', '#GJ0VVQ8V', '#898889VR', '#LV88Y908', '#YCRVC2QG', '#Q0PULQU0', '#QU2PG9GL', '#80PV8QR', '#G2Y288R9', '#G9RJ9CLQ', '#Q2J0U288', '#LGGRJLUR', '#PJGRQ2PJ', '#YYP99RJ2', '#Q9P0CC0G', '#PPJLQJPQ', '#20LPPG89', '#Y0UVCY2', '#8Y0QYLC', '#QR0U9UY8', '#LJU8LRV9', '#QU2JCRLP', '#LGPVVYUU', '#GPQ82P8C', '#88JRLQCV', '#LUPQJ2YY', '#LV80J0', '#QU90RYUC', '#R208JV', '#PC2VQ9L2', '#LJULUV8Q', '#QQPR2CVC', '#P82P9U9P', '#22VVP928', '#L280R9QP', '#28J8LGVP', '#LU9GYQ0P', '#YGR0QL2L', '#20VV0CG', '#QPPJCPJ9', '#LGPPCU9U', '#Y0YPC8CJ', '#Q0RJ9LQ2', '#2RVCJRL', '#9L02Y0', '#CCRYGRY', '#9PUUPVJU', '#LR80QG0G', '#8Y2YRRQ8', '#2V089P09', '#QPRP9GYY', '#QJ2802', '#P9U9UQC2', '#PY0P8L', '#QC89GRYU', '#Q0JCJCJV', '#GYL28VPQ', '#YLC0RY2U', '#P8UJ9JV9', '#VVPRL9U', '#QQU8LR2V', '#899Y8J', '#P0QC899', '#QCJG09LJ', '#29P0L8GR', '#LYQJP08R', '#LU0LUP08', '#GQ0Y9UVC', '#LVGYLYYJ', '#8P8YPLL', '#QP8QQUPP', '#L022PG9C', '#QPLPVUJG', '#QYC2QPC2', '#LGUJGVYP', '#Q9URV9PR', '#82J8UVQV', '#CJJ9UVP', '#YGLC0VU2', '#YJV209YR', '#LUJ89R8Y', '#9PULCJPL', '#2YGJJPLV', '#LR8JVP0G', '#LQL0RURQ', '#YUR900R0', '#L9VV99UQ', '#G9UULUUC', '#GQVRQ2UP', '#GLQC0JP9', '#YUUVU0CP', '#GQ90YU20', '#LVUP2GY8', '#9JLYUL', '#UR29QCV', '#LG8G8C00', '#LJCCJCCP', '#PGLG2RU9', '#Y98J2L2Y', '#YVQQPY22', '#QJY8VG8U', '#9VPY09L9', '#2P8GVQVG', '#Q8VYYPV2', '#2V00C98J', '#QVVYLRRL', '#Q89UUV9C', '#2QUU2RP', '#829P8QPL', '#P9YJU88Q', '#22RCPQ', '#QJ9LL22Q', '#8VCGQL82', '#G9V9CJYY', '#8Y2JQG9V', '#RLLRUC9', '#LY8UUPC9', '#GLGVVQ8C', '#9RPP2QRJ', '#YG009C2R', '#J2GC2', '#90YJ992U', '#LL92LQ9C', '#PG0LGU', '#9QGVLJ', '#GR0880LL', '#CPPPQGG', '#JPLUJQ2', '#LC8C0UVQ', '#Q0VYQJ8Q', '#8P00L8P2', '#L2RJGULY', '#9VY0P9VV', '#GYUJ2QV0', '#QUYCCPC8', '#8GR908', '#LU8R8JCR', '#22J0VQ2', '#Q0VRVP8V', '#Q9PVRJQ2', '#LQ0GJ0CP', '#LPJR2V0P', '#L2V2LCCL', '#GP0CL2G0', '#8PRL2JGR', '#CQUYLLU', '#92PLYLQ0', '#LG2R9C22', '#QU0R8PCU', '#YJJQQ9GU', '#Q2YC2GG9', '#L0QJLQUQ', '#LRJLCLG', '#QVQVPPRJ', '#QVRPG9PY', '#P0LQCPR8', '#2GPCCVU2', '#8PG9JJ2Q', '#9JGCVY', '#GP9GGLV8', '#LJ098QCG', '#200L9CJC', '#2YRYPVQ8', '#LVRJUGC8', '#YY82RVP2', '#YYQY2QVU', '#LV0VPLGV', '#LVQCLJ0G', '#2YUYYPR', '#LULQ8UVL', '#GLYPLPUC', '#L2998RCY', '#L9RGURQG', '#PP2Q0L8L', '#QR2200RP', '#Q00C09V0', '#9J0PC9C9', '#8Q2J9CPQ', '#LV20UU82', '#GQ0VY8RL', '#8QR282PC', '#228Q9JGP', '#QP998JV0', '#9C0V8GRV', '#LJVL989P', '#QUV8GQ0G', '#9L0V2QY8', '#GLUU0C0Y', '#L0JJL2V2', '#YV0CULQ2', '#YVJV9PRC', '#QUJR0LVV', '#YV8PVJYU', '#QPRR008V', '#2J00LCGG', '#P89LCQV', '#2R9CJYC', '#YLCC0QQQ', '#G9VGLLCV', '#LCLQJGPG', '#Q8YUGGR', '#YYGGR90L', '#2C2RP829', '#LPPV8902', '#GQC22CJJ', '#2GRG89JY', '#L0CL2VLG', '#L9V9QCPC', '#2L0QC89', '#G ...
# 960

# %% [markdown]
# ## Part 2 - Obtaining Individual Player Data
# The data is then further cleaned to obtained all the members within those clans, which will then be further cleaned by only obtaining the tag id, which then the id will allow us to once again use API to request individidual player data.

# %%
api_token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..sSg_bToWcK6yTwmx0wxNKsFM4jpjH93henx1Mypv4ej-PNR-h9iM_bmR9xXEeepymPyyGe7dT6iCUY0bLLXl5A'
ecrypted_clan_tag = [urllib.parse.quote(tag) for tag in tags[:100]]
player_tag=[]

for tag in ecrypted_clan_tag:
    try:
        url = f'https://api.clashroyale.com/v1/clans/{tag}/members'
        headers = {'Authorization': f'Bearer {api_token}'}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        members = response.json()['items']
        for member in members:
            player_tag.append(member["tag"])
    except requests.exceptions.HTTPError as err:
        print(f'Error retrieving member list for clan {tag}: {err}')
    except Exception as err:
        print(f'Unexpected error for clan {tag}: {err}')

print(player_tag)
# Out:
# ['#9URJPGLRV', '#Q0CJJ2RP', '#RUV9CYUV0', '#Q2GR9ULY9', '#9JQVJ8Y90', '#QRP0V9GJ9', '#UJPR2RJ2L', '#LQY0J9GRY', '#JPRR00U', '#V8URCG28', '#YJ889LG9Q', '#8988CYY9V', '#UVY0VJUP2', '#2RCUGR0YY', '#UQ0G2Y9U2', '#GCUC02LUG', '#JU2P0Q92Y', '#GCUY808J2', '#CCGJC2VQ8', '#9RJGC2PJU', '#8YRVQ00U', '#GLGGUPPRL', '#CVYJ8C9PR', '#C8P88UUYJ', '#J80L0PCCL', '#JVPPJ29Q8', '#CYC92UPLV', '#CGQ0RQPUC', '#U0QG88J99', '#C9V9L0LUU', '#CVYR2VR2L', '#JYGPV0U8J', '#JY8C0QULG', '#V9889RGU8', '#U09GQJ89Q', '#UC98Q9YVG', '#CJJJCVJ8C', '#G2CR299LU', '#CR29J9Y0C', '#U9VL2L89C', '#UGQUC20GQ', '#CLGJR200J', '#URJUCYGPQ', '#UGQGJLUPL', '#CRP2PR28C', '#RUCY2VYCJ', '#V20PC0RJJ', '#CGG09CJYG', '#V8C8U0292', '#UVCGPRP89', '#9P8YRQVV0', '#2VGVVG2V', '#2YJRRUJR0', '#8GYY2L2P', '#2J0VYUCQG', '#8LL9JJ09C', '#L0R9029G', '#LVQ8P9GJ', '#9Q9LLRL9V', '#8PJRVCLGV', '#RJUPP9P2', '#P2RUV09', '#2L2RQVVYR', '#8PCG0QJJ', '#882U9YGGU', '#GJQR0QQ22', '#29Q92LCL0', '#JPUQLVQ', '#RQUU88C82', '#Y8GLVLUG0', '#L8L92LC8C', '#2C8L80GRG', '#898RQU8J8', '#LRY90RLVR', '#22G9VCPYG', '#CCLQ0LCL8', '#Y99Q8G8G', '#UGP0Q200J', '#2GLRQGRC', '#G9YPUCVYJ', '#89GLRQPV2', '#RV2U202L', '#UGP8GV9P8', '#GP0QUUPC9', '#JGCVCLQJR', '#QCRLV0LP', '#Y9C8VG0G8', '#LPQJLR9JL', '#9Y9Q8RJQP', '#PPG2UG9RP', '#G82LQYYUP', '#8QLQLVG9J', '#89G08VG2U', '#8LYJVQ0PU', '#92JCL8VCU', '#CGYU0C0R', '#Q8RPQ9L9L', '#C02P2CQ0Y', '#YRQQ0QCPU', '#92GRULL2C', '#ULYQ9CGC2', '#U8JJG8QJQ', '#9RVPCCU0R', '#CJ9L0RULC', '#CUY0VQLYC', '#JY22Q99J8', '#JRPQQRUY8', '#UV9VYUGG0', '#VYR02VJLL', '#U088Y9VL9', '#VYJQ08PJ0', '#CJ8Y2Y99U', '#CCU90ULVR', '#VLQQPVJ29', '#CCU920LYQ', '#U0L89QQP9', '#UVQPCUR9G', '#CUC8YJ9VP', '#U02QRP2GU', '#CCLGLJUYJ', '#VLQG98GUQ', '#UQRRYJLQ8', '#UJUQUJJQC', '#VPRLUQCGY', '#UUPP8YQRV', '#URRP9JVJ8', '#UVVUGGQLY', '#V8R0YLG9J', '#CJ8Q8PYJY', '#CUCP2LVGY', '#V8R0QQ0GU', '#VLQYPRYR9', '#CJGRQCJ8P', '#CV9Q88YPL', '#UUPP8VYL0', '#VPRRQG22J', '#V9UR8QVUC', '#CCPCRYPVP', '#U229PQYJR', '#UV9YQYGLP', '#VPLQQJLLY', '#UQ0LCVG9R', '#U2LQ8LVJY', '#CCC888Q2Q', '#V99LURC0P', '#RV0PYY8CQ', '#UU09989JL', '#UCY22QGYP', '#UCY9ULL2C', '#U0Q2GGG2Q', '#U02P8C8VV', '#U02YVYY9C', '#UVQLPVJQ9', '#CUC8JUVYU', '#U0Q8PRUUY', '#V9JQUL29J', '#CUCYUPP9C', '#U02G09GRJ', '#UQRCLY202', '#CUCRG22QR', '#CCUP22JC0', '#V9J92RV0V', '#U02PCQPRV', '#U0Q2JY2GC', '#UUP9Q8L0J', '#CV8YYVQUP', '#UCYLGUQCC', '#U0Q8JGU0Q', '#UUPLP0VUY', '#CUCQLRU8G', '#CUCPQJJRG', '#VYGY0Y0V2', '#VLQG8YURR', '#CV99C9VLP', '#CUCP2PY0R', '#V8GVVUYJP', '#UCY2CURYY', '#CVQ0928LC', '#CGCLP2V8P', '#UUU0RV0PQ', '#CG9C8LG28', '#CCRCCCQUY', '#CPGLPQYVV', '#V0Q90U2LU', '#U2YQ9UQ0R', '#V09CPC9YV', '#CJ80CRJV0', '#CCC0C8J0Q', '#UQQG2C288', '#VPQLVQ2J2', '#UVY2PGC2J', '#UU8GYC0QL', '#VPQJPPGQG', '#CV2C8GGCQ', '#CJ89V928V', '#CJG22CG0U', '#UU8GP092Y', '#UY0QJGP0J', '#VPQQR8PPP', '#CJ8P0YPLR', '#CVUUU282P', '#CV2QJPUG9', '#U0Y02CGVR', '#CCL8RLC0Q', '#CVVQ9V88Y', '#UJULGGUG9', '#VPQPPJC20', '#U0YLLGC0J', '#CVV8PC2CU', '#CCUL2PYJL', '#UQG0LVY20', '#U0PPJ2YQ2', '#UVYLQ9809', '#CUGUJUJCC', '#VLYPLJY0J', '#CJ8P9QGUY', '#V8LRJGRJY', '#VQ298U8RC', '#VP0LUGRRL', '#V9Y8QCYRL', '#VQG0Q2802', '#CJ8Y8UYJ9', '#CRJYCCP02', '#CCLRVGUGL', '#CCL9CJVCR', '#UJLJLJVLC', '#UPGCC80LL', '#VPGUPVCCC', '#CV8JGCCQV', '#CV8JCJ92J', '#UQR908JCG', '#V8GP8UCRC', '#UQR800VU0', '#UVLJLGLUP', '#CC08LYLPJ', '#V8GQ9URLU', '#UU9C0LGYR', '#CUC89Y0VR', '#CJ8Y02Q28', '#UVLVR2PQC', '#U0LGCCLQ9', '#U00QG0GYU', '#CCYPGVCRV', '#CUJJU2G9P', '#CV900RYGL', '#V8GYRY0UL', '#VLQ2JRGLP', '#CV922VQ80', '#U0LGUVRJU', '#UR9Y9G0JL', '#UQR8U8YJC', '#UQR900GC0', '#CVUPYCUC9', '#UCRYLPUJ9', '#U0VUPUQ2R', '#QRVJY92Q2', '#V8R8YVRU0', '#VLQQYCQV9', '#VLQQGRJUR', '#V8R8LQ9R8', '#UVL9UGR9G', '#V9YGVY2PV', '#UPQCY0989', '#V8R0UY9YU', '#VLQJVQ8YJ', '#UQRVCLQCQ', '#UR8Y9PGJ8', '#CJV82P2LJ', '#UR8GQ0QL2', '#UVQR0P2LV', '#U0QP8UQVY', '#V2QQRV288', '#UJYJGJYCG', '#VLQRJYPY2', '#UQRCU20PC', '#UVQYR920G', '#UQRCCUPLQ', '#CRRGC0QPY', '#CV9YP0V9L', '#V8R0CCYRU', '#UUPLYG8Y2', '#V8GVYPCP2', '#CUCL9C29P', '#U02LRL9QY', '#UPQV098Y9', '#CUCCLJJQV', '#CUCLPURY0', ' ...

# %%
print("Total Player Sample Size:", len(player_tag))
# Out:
# Total Player Sample Size: 3695

# %%
players = []
ecrypted_tags = [urllib.parse.quote(tag) for tag in player_tag]

def fetch_player_info(tag):
    try:
        url = f'https://api.clashroyale.com/v1/players/{tag}'
        headers = {'Authorization': f'Bearer {api_token}'}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        player_info = response.json()
        return player_info
    except requests.exceptions.HTTPError as err:
        print(f'Error retrieving member list for clan {tag}: {err}')
    except Exception as err:
        print(f'Unexpected error for clan {tag}: {err}')

with concurrent.futures.ThreadPoolExecutor() as executor:
    future_to_tag = {executor.submit(fetch_player_info, tag): tag for tag in ecrypted_tags}
    for future in concurrent.futures.as_completed(future_to_tag):
        tag = future_to_tag[future]
        player_info = future.result()
        players.append(player_info)

# %%
headers = list(players[0].keys())

# Open a new CSV file in write mode
with open('player_info.csv', 'w', newline='', encoding='utf-8') as file:

    # Create a CSV writer object
    writer = csv.DictWriter(file, fieldnames=headers)

    # Write the headers to the CSV file
    writer.writeheader()

    # Write each dictionary to the CSV file as a row
    for row in players:
        writer.writerow(row)

# %%
df=pd.read_csv("player_info.csv")
df.head(20)
# Out:
#            tag           name  expLevel  trophies  bestTrophies  wins  losses  \
# 0    #Q0CJJ2RP           POMA        40      6520          6741  3567    3537
# 1   #8988CYY9V          $@Rc!        33      5689          5713  1297    1005
# 2   #RUV9CYUV0    *DANGEROUS*        40      6135          6184  1962    1782
# 3   #UJPR2RJ2L     xkramerinx        34      5875          5875   693     393
# 4   #9JQVJ8Y90  Dark Master ☆        36      6008          6008  3584    2862
# 5    #V8URCG28           ryuk        37      5779          5779  1829    1491
# 6   #LQY0J9GRY          <FER>        41      5842          6006  2280    1558
# 7     #JPRR00U         marcos        37      5802          5802  2404    1925
# 8   #QRP0V9GJ9    ReyJose2005        40      6000          6168  2674    2983
# 9   #9URJPGLRV           ROKO        41      6795          6890  3391    3121
# 10  #Q2GR9ULY9           Kris        41      6068          6211  2241    1908
# 11  #YJ889LG9Q            jos        43      5777          5803  3146    3575
# 12  #UVY0VJUP2      Beltron-_        37      5686          5766   457     176
# 13  #2RCUGR0YY   ~el asesino~        37      5654          5654  3570    3451
# 14  #UQ0G2Y9U2        snayder        31      5514          5518   600     268
# 15  #GCUC02LUG      anderson¡        34      5330          5454  1460    1686
# 16  #JU2P0Q92Y  Diego pro:)12        36      5326          5420   932     786
# 17  #GCUY808J2           阿列克斯        40      5317          5512  1543    1363
# 18  #CCGJC2VQ8     ANCARAMESI        27      5303          5316   644     164
# 19   #8YRVQ00U      chevanton        41      5232          5299  2214    2795
#
#     battleCount  threeCrownWins  challengeCardsWon  ...  \
# 0          9554            2815               1128  ...
# 1          3356             913                424  ...
# 2          8013            1451                312  ...
# 3          1239             399                  0  ...
# 4          7953            1053               2191  ...
# 5          5935            1591                819  ...
# 6          4697            1943                 20  ...
# 7          6211             887               2810  ...
# 8          7253            2080                  5  ...
# 9          7571            1591                336  ...
# 10         6997            1531                 99  ...
# 11         7922            1777                  5  ...
# 12         2663             888                  0  ...
# 13        12900            1430               1780  ...
# 14         1106             298                  0  ...
# 15         3437             757                 57  ...
# 16         2659             868                 25  ...
# 17         3523            1418                 53  ...
# 18          841             209                 38  ...
# 19         6916            1523               1080  ...
#
#                                    arena  \
# 0   {'id': 54000015, 'name': 'Arena 18'}
# 1   {'id': 54000013, 'name': 'Arena 16'}
# 2   {'id': 54000014, 'name': 'Arena 17'}
# 3   {'id': 54000013, 'name': 'Arena 16'}
# 4   {'id': 54000014, 'name': 'Arena 17'}
# 5   {'id': 54000013, 'name': 'Arena 16'}
# 6   {'id': 54000013, 'name': 'Arena 16'}
# 7   {'id': 54000013, 'name': 'Arena 16'}
# 8   {'id': 54000014, 'name': 'Arena 17'}
# 9   {'id': 54000015, 'name': 'Arena 18'}
# 10  {'id': 54000014, 'name': 'Arena 17'}
# 11  {'id': 54000013, 'name': 'Arena 16'}
# 12  {'id': 54000013, 'name': 'Arena 16'}
# 13  {'id': 54000013, 'name': 'Arena 16'}
# 14  {'id': 54000012, 'name': 'Arena 15'}
# 15  {'id': 54000012, 'name': 'Arena 15'}
# 16  {'id': 54000012, 'name': 'Arena 15'}
# 17  {'id': 54000012, 'name': 'Arena 15'}
# 18  {'id': 54000056, 'name': 'Arena 14'}
# 19  {'id': 54000012, 'name': 'Arena 15'}
#
#                                      leagueStatistics  \
# 0   {'currentSeason': {'trophies': 6520, 'bestTrop...
# 1   {'currentSeason': {'trophies': 5689, 'bestTrop...
# 2   {'currentSeason': {'trophies': 6135, 'bestTrop...
# 3   {'currentSeason': {'trophies': 5875, 'bestTrop...
# 4   {'currentSeason': {'trophies': 6008, 'bestTrop...
# 5   {'currentSeason': {'trophies': 5779, 'bestTrop...
# 6   {'currentSeason': {'trophies': 5842, 'bestTrop...
# 7   {'currentSeason': {'trophies': 5802, 'bestTrop...
# 8   {'currentSeason': {'trophies': 6000, 'bestTrop...
# 9   {'currentSeason': {'trophies': 6795, 'bestTrop...
# 10  {'currentSeason': {'trophies': 6068, 'bestTrop...
# 11  {'currentSeason': {'trophies': 5777, 'bestTrop...
# 12  {'currentSeason': {'trophies': 5686}, 'previou...
# 13  {'currentSeason': {'trophies': 5654, 'bestTrop...
# 14                                                NaN
# 15  {'currentSeason': {'trophies': 5330}, 'previou...
# 16  {'currentSeason': {'trophies': 5326, 'bestTrop...
# 17  {'currentSeason': {'trophies': 5317, 'bestTrop...
# 18                                                NaN
# 19  {'currentSeason': {'trophies': 5232, 'bestTrop...
#
#                                                badges  \
# 0   [{'name': 'YearsPlayed', 'level': 5, 'maxLevel...
# 1   [{'name': 'YearsPlayed', 'level': 5, 'maxLevel...
# 2   [{'name': 'YearsPlayed', 'level': 1, 'maxLevel...
# 3   [{'name': 'EmoteCollection', 'level': 1, 'maxL...
# 4   [{'name': 'YearsPlayed', 'level': 4, 'maxLevel...
# 5   [{'name': 'YearsPlayed', 'level': 6, 'maxLevel...
# 6   [{'name': 'YearsPlayed', 'level': 3, 'maxLevel...
# 7   [{'name': 'YearsPlayed', 'level': 6, 'maxLevel...
# 8   [{'name': 'YearsPlayed', 'level': 2, 'maxLevel...
# 9   [{'name': 'YearsPlayed', 'level': 5, 'maxLevel...
# 10  [{'name': 'YearsPlayed', 'level': 2, 'maxLevel...
# 11  [{'name': 'YearsPlayed', 'level': 3, 'maxLevel...
# 12  [{'name': 'BattleWins', 'level': 3, 'maxLevel'...
# 13  [{'name': 'YearsPlayed', 'level': 6, 'maxLevel...
# 14  [{'name': 'EmoteCollection', 'level': 1, 'maxL...
# 15  [{'name': 'YearsPlayed', 'level': 2, 'maxLevel...
# 16  [{'name': 'YearsPlayed', 'level': 1, 'maxLevel...
# 17  [{'name': 'YearsPlayed', 'level': 1, 'maxLevel...
# 18  [{'name': 'EmoteCollection', 'level': 1, 'maxL...
# 19  [{'name': 'YearsPlayed', 'level': 6, 'maxLevel...
#
#                                          achievements  \
# 0   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 1   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 2   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 3   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 4   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 5   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 6   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 7   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 8   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 9   [{'name': 'Team Player', 'stars': 3, 'value': ...
# 10  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 11  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 12  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 13  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 14  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 15  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 16  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 17  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 18  [{'name': 'Team Player', 'stars': 3, 'value': ...
# 19  [{'name': 'Team Player', 'stars': 3, 'value': ...
#
#                                                 cards  \
# 0   [{'name': 'Night Witch', 'id': 26000048, 'leve...
# 1   [{'name': 'Goblin Barrel', 'id': 28000004, 'le...
# 2   [{'name': 'Elixir Collector', 'id': 27000007, ...
# 3   [{'name': 'Tornado', 'id': 28000012, 'level': ...
# 4   [{'name': 'Goblins', 'id': 26000002, 'level': ...
# 5   [{'name': 'Royal Giant', 'id': 26000024, 'leve...
# 6   [{'name': 'Goblins', 'id': 26000002, 'level': ...
# 7   [{'name': 'Elixir Collector', 'id': 27000007, ...
# 8   [{'name': 'Archers', 'id': 26000001, 'level': ...
# 9   [{'name': 'Flying Machine', 'id': 26000057, 'l...
# 10  [{'name': 'Goblins', 'id': 26000002, 'level': ...
# 11  [{'name': 'Rascals', 'id': 26000053, 'level': ...
# 12  [{'name': 'Battle Ram', 'id': 26000036, 'level...
# 13  [{'name': 'Golem', 'id': 26000009, 'level': 5,...
# 14  [{'name': 'Goblins', 'id': 26000002, 'level': ...
# 15  [{'name': 'Elixir Collector', 'id': 27000007, ...
# 16  [{'name': 'Mortar', 'id': 27000002, 'level': 1...
# 17  [{'name': 'Night Witch', 'id': 26000048, 'leve...
# 18  [{'name': 'Electro Giant', 'id': 26000085, 'le...
# 19  [{'name': 'Clone', 'id': 28000013, 'level': 5,...
#
#                                           currentDeck  \
# 0   [{'name': 'X-Bow', 'id': 27000008, 'level': 9,...
# 1   [{'name': 'Arrows', 'id': 28000001, 'level': 1...
# 2   [{'name': 'Firecracker', 'id': 26000064, 'leve...
# 3   [{'name': 'Barbarians', 'id': 26000008, 'level...
# 4   [{'name': 'Zap', 'id': 28000008, 'level': 14, ...
# 5   [{'name': 'Golem', 'id': 26000009, 'level': 9,...
# 6   [{'name': 'Balloon', 'id': 26000006, 'level': ...
# 7   [{'name': 'Archers', 'id': 26000001, 'level': ...
# 8   [{'name': 'Mirror', 'id': 28000006, 'level': 9...
# 9   [{'name': 'Valkyrie', 'id': 26000011, 'level':...
# 10  [{'name': 'The Log', 'id': 28000011, 'level': ...
# 11  [{'name': 'Musketeer', 'id': 26000014, 'level'...
# 12  [{'name': 'Rocket', 'id': 28000003, 'level': 1...
# 13  [{'name': 'The Log', 'id': 28000011, 'level': ...
# 14  [{'name': 'Goblin Barrel', 'id': 28000004, 'le...
# 15  [{'name': 'Hog Rider', 'id': 26000021, 'level'...
# 16  [{'name': 'Mega Knight', 'id': 26000055, 'leve...
# 17  [{'name': 'Clone', 'id': 28000013, 'level': 5,...
# 18  [{'name': 'Electro Spirit', 'id': 26000084, 'l...
# 19  [{'name': 'Electro Wizard', 'id': 26000042, 'l...
#
#                                  currentFavouriteCard  starPoints  expPoints  \
# 0   {'name': 'Knight', 'id': 26000000, 'maxLevel':...        6161        631
# 1   {'name': 'Skeleton King', 'id': 26000069, 'max...        3931       4191
# 2   {'name': 'Hog Rider', 'id': 26000021, 'maxLeve...       38754      21160
# 3   {'name': 'Electro Dragon', 'id': 26000063, 'ma...       15439       3949
# 4   {'name': 'Electro Giant', 'id': 26000085, 'max...       58550       7208
# 5   {'name': 'Golem', 'id': 26000009, 'maxLevel': ...       31004       5619
# 6   {'name': 'Giant', 'id': 26000003, 'maxLevel': ...       19468      19693
# 7   {'name': 'Valkyrie', 'id': 26000011, 'maxLevel...       14890        670
# 8   {'name': 'Mega Knight', 'id': 26000055, 'maxLe...       27031      13773
# 9   {'name': 'Baby Dragon', 'id': 26000015, 'maxLe...       70254       8199
# 10  {'name': 'Inferno Tower', 'id': 27000003, 'max...       31568      18478
# 11  {'name': 'Golem', 'id': 26000009, 'maxLevel': ...       12155      17355
# 12  {'name': 'Electro Giant', 'id': 26000085, 'max...        9834       5949
# 13  {'name': 'Giant Skeleton', 'id': 26000020, 'ma...       94276       6381
# 14  {'name': 'Hog Rider', 'id': 26000021, 'maxLeve...       18516       3491
# 15  {'name': 'P.E.K.K.A', 'id': 26000004, 'maxLeve...        3355      10785
# 16  {'name': 'X-Bow', 'id': 27000008, 'maxLevel': ...       16916       9236
# 17  {'name': 'Hog Rider', 'id': 26000021, 'maxLeve...       46304       4614
# 18  {'name': 'Prince', 'id': 26000016, 'maxLevel':...       41296       3776
# 19  {'name': 'Mother Witch', 'id': 26000083, 'maxL...        2268      13758
#
#    totalExpPoints
# 0          157401
# 1           66961
# 2          177930
# 3           77719
# 4          105978
# 5          116889
# 6          198463
# 7          111940
# 8          170543
# 9          186969
# 10         197248
# 11         246125
# 12         117219
# 13         117651
# 14          49261
# 15          84555
# 16         108006
# 17         161384
# 18          26546
# 19         192528
#
# [20 rows x 30 columns]

# %% [markdown]
# ## Part 3 - Obtaining Player Battle Log
# Through the individual player data, we can futher get player recent battle log through the same API call, which we will use asl for our initial analytic. We will first be taking only the first 3 top battles of each players into account. then putting them into a singular list

# %%
df = pd.read_csv("../Common/player_df_cleaned")
df.head(3)
tags=[]
for i in df['tag']:
    tags.append(i)

ecrypted_tags = [urllib.parse.quote(tag) for tag in tags]

# %%
players_battles=[]
api_token = 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9.....sBm6VvsBbUhVh97Dv-TLcOpIb_rrIZudjb2ipzV-iquyVjqY0CbCQYVB6XbOZgqS9F-5UEa7j0sjukZeMEHZvg'

def fetch_battle_log(tag):
    try:
        url = f'https://api.clashroyale.com/v1/players/{tag}/battlelog'
        headers = {'Authorization': f'Bearer {api_token}'}
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        player_info = response.json()
        players_battles.append(player_info)
    except requests.exceptions.HTTPError as err:
        print(f'Error retrieving player {tag}: {err}')
    except Exception as err:
        print(f'Unexpected error for player {tag}: {err}')

with concurrent.futures.ThreadPoolExecutor() as executor:
    future_to_tag = {executor.submit(fetch_battle_log, tag): tag for tag in ecrypted_tags}
    for future in concurrent.futures.as_completed(future_to_tag):
        tag = future_to_tag[future]
        player_info = future.result()
        players_battles.append(player_info)

# %%
print(players_battles[:3])
# Out:
# [[{'type': 'seasonalBattle', 'battleTime': '20230403T030544.000Z', 'isLadderTournament': False, 'arena': {'id': 54000038, 'name': 'Legendary Arena'}, 'gameMode': {'id': 72000343, 'name': 'Event_GoblinPartyRocket'}, 'deckSelection': 'eventDeck', 'team': [{'tag': '#UVY0VJUP2', 'name': 'Beltron-_', 'startingTrophies': 5899, 'crowns': 1, 'kingTowerHitPoints': 3075, 'princessTowersHitPoints': [199, 1193], 'clan': {'tag': '#LJQYQ9VC', 'name': '#HailGrasaPapu', 'badgeId': 16000024}, 'cards': [{'name': None, 'id': 28000020, 'level': 3, 'maxLevel': 0}, {'name': 'Mini P.E.K.K.A', 'id': 26000018, 'level': 9, 'starLevel': 2, 'maxLevel': 12, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/Fmltc4j3Ve9vO_xhHHPEO3PRP3SmU2oKp2zkZQHRZT4.png'}}, {'name': 'Ram Rider', 'id': 26000051, 'level': 3, 'maxLevel': 6, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/QaJyerT7f7oMyZ3Fv1glKymtLSvx7YUXisAulxl7zRI.png'}}, {'name': 'Wizard', 'id': 26000017, 'level': 9, 'starLevel': 1, 'maxLevel': 12, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/Mej7vnv4H_3p_8qPs_N6_GKahy6HDr7pU7i9eTHS84U.png'}}, {'name': 'Dark Prince', 'id': 26000027, 'level': 6, 'starLevel': 1, 'maxLevel': 9, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/M7fXlrKXHu2IvpSGpk36kXVstslbR08Bbxcy0jQcln8.png'}}, {'name': 'The Log', 'id': 28000011, 'level': 3, 'maxLevel': 6, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/_iDwuDLexHPFZ_x4_a0eP-rxCS6vwWgTs6DLauwwoaY.png'}}, {'name': 'Skeleton Army', 'id': 26000012, 'level': 6, 'starLevel': 1, 'maxLevel': 9, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/fAOToOi1pRy7svN2xQS6mDkhQw2pj9m_17FauaNqyl4.png'}}, {'name': 'Dart Goblin', 'id': 26000040, 'level': 9, 'maxLevel': 12, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/BmpK3bqEAviflqHCdxxnfm-_l3pRPJw3qxHkwS55nCY.png'}}], 'elixirLeaked': 2.9}], 'opponent': [{'tag': '#U00CCLC29', 'name': 'Gabriela', 'startingTrophies': 4207, 'crowns': 0, 'kingTowerHitPoints': 3075, 'princessTowersHitPoints': [1303], 'clan': {'tag': '#2RVURUU0', 'name': 'JINETES ROYALE', 'badgeId': 16000151}, 'cards': [{'name': None, 'id': 28000020, 'level': 3, 'maxLevel': 0}, {'name': 'Ice Spirit', 'id': 26000030, 'level': 11, 'maxLevel': 14, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/lv1budiafU9XmSdrDkk0NYyqASAFYyZ06CPysXKZXlA.png'}}, {'name': 'Skeletons', 'id': 26000010, 'level': 11, 'maxLevel': 14, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/oO7iKMU5m0cdxhYPZA3nWQiAUh2yoGgdThLWB1rVSec.png'}}, {'name': 'Fire Spirit', 'id': 26000031, 'level': 11, 'maxLevel': 14, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/16-BqusVvynIgYI8_Jci3LDC-r8AI_xaIYLgXqtlmS8.png'}}, {'name': 'Cannon', 'id': 27000000, 'level': 11, 'maxLevel': 14, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/nZK1y-beLxO5vnlyUhK6-2zH2NzXJwqykcosqQ1cmZ8.png'}}, {'name': 'Skeleton Army', 'id': 26000012, 'level': 6, 'maxLevel': 9, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/fAOToOi1pRy7svN2xQS6mDkhQw2pj9m_17FauaNqyl4.png'}}, {'name': 'The Log', 'id': 28000011, 'level': 3, 'maxLevel': 6, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/_iDwuDLexHPFZ_x4_a0eP-rxCS6vwWgTs6DLauwwoaY.png'}}, {'name': 'Heal Spirit', 'id': 28000016, 'level': 9, 'maxLevel': 12, 'iconUrls': {'medium': 'https://api-assets.clashroyale.com/cards/300/GITl06sa2nGRLPvboyXbGEv5E3I-wAwn1Eqa5esggbc.png'}}], 'elixirLeaked': 8.22}], 'isHostedMatch': False}, {'type': 'seasonalBattle', 'battleTime': '20230403T025400.000Z', 'isLadderTournament': False, 'arena': {'id': 54000038, 'name': 'Legendary Arena'}, 'gameMode': {'id': 72000343, 'name': 'Event_GoblinPartyRocket'}, 'deckSelection': 'eventDeck', 'team': [{'tag': '#UVY0VJUP2', 'name': 'Beltron-_', 'startingTrophies': 5899, 'crowns': 1, 'kingTowerHitPoints': 4824, 'princessTowersHitP ...

# %%
combined_battles=[]
for player in players_battles:
    if player is None or len(player) < 5:
        continue
    for i in range(5):
        combined_battles.append(player[i])
keys = set()
for d in combined_battles:
    keys.update(d.keys())


# Convert the keys set to a list
headers = list(keys)
with open('../Common/battle_logs_info.csv', 'w', newline='', encoding='utf-8') as file:

    # Create a CSV writer object
    writer = csv.DictWriter(file, fieldnames=headers)

    # Write the headers to the CSV file
    writer.writeheader()

    # Write each dictionary to the CSV file as a row
    for row in combined_battles:
        # Fill in missing values for keys not present in the dictionary
        for key in headers:
            row.setdefault(key, None)
        writer.writerow(row)
